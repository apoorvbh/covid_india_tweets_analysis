# %%
import pandas as pd
import os
import json
import preprocessor as p

from datetime import datetime, timedelta

# %%
def get_location_dataframe(tweet_df, column_name):
    location_df = pd.DataFrame()

    location_df[column_name + '_country_code'] = tweets_df[column_name].apply(lambda x: x.get('country_code'))
    location_df[column_name + '_state'] = tweets_df[column_name].apply(lambda x: x.get('state'))
    location_df[column_name + '_county'] = tweets_df[column_name].apply(lambda x: x.get('county'))
    location_df[column_name + '_city'] = tweets_df[column_name].apply(lambda x: x.get('city'))

    return location_df

# %%
extracted_tweets_files_dir = 'extracted_tweets_files'
filtered_tweets_files_dir = 'filtered_tweets_files'
hydrated_tweets_files_dir = 'hydrated_tweets_files'
cleaned_tweets_files_dir = 'cleaned_tweets_files'

tweet_file_name_template = 'en_geo_{}.{}'
extracted_tweets_file_type = 'json'
filtered_tweets_file_type = 'txt'
cleaned_tweets_file_type = 'csv'

extracted_tweet_file_name = tweet_file_name_template.format('2020-02-01', extracted_tweets_file_type)
extracted_tweets_file = os.path.join(extracted_tweets_files_dir, extracted_tweet_file_name)

filtered_tweet_file_name = tweet_file_name_template.format('2020-02-01', filtered_tweets_file_type)
filtered_tweets_file = os.path.join(filtered_tweets_files_dir, filtered_tweet_file_name)

hydrated_tweet_file_name = tweet_file_name_template.format('2020-02-01', filtered_tweets_file_type)
hydrated_tweets_file = os.path.join(hydrated_tweets_files_dir, hydrated_tweet_file_name)

cleaned_tweet_file_name = tweet_file_name_template.format('2020-02-01', cleaned_tweets_file_type)
cleaned_tweets_file = os.path.join(cleaned_tweets_files_dir, cleaned_tweet_file_name)

print(extracted_tweets_file)
print(filtered_tweets_file)
print(hydrated_tweets_file)
print(cleaned_tweets_file)
# Out:
# extracted_tweets_files\en_geo_2020-02-01.json
# filtered_tweets_files\en_geo_2020-02-01.txt
# hydrated_tweets_files\en_geo_2020-02-01.txt
# cleaned_tweets_files\en_geo_2020-02-01.csv

# %%
with open(extracted_tweets_file) as f:
    tweets_df = pd.read_json(f, lines = True)

# %%
user_location_df = get_location_dataframe(tweets_df, 'user_location')
geo_df = get_location_dataframe(tweets_df, 'geo')
place_df = get_location_dataframe(tweets_df, 'place')

refined_tweets_df = pd.concat([tweets_df, user_location_df, geo_df, place_df], axis = 1)

# %%
refined_tweets_df['tweet_locations_country_code'] = refined_tweets_df['tweet_locations']\
.apply(lambda x: list(map(lambda y: y.get('country_code'), x)))

refined_tweets_df['tweet_locations_state'] = refined_tweets_df['tweet_locations']\
.apply(lambda x: list(map(lambda y: y.get('state'), x)))

refined_tweets_df['tweet_locations_county'] = refined_tweets_df['tweet_locations']\
.apply(lambda x: list(map(lambda y: y.get('county'), x)))

refined_tweets_df['tweet_locations_city'] = refined_tweets_df['tweet_locations']\
.apply(lambda x: list(map(lambda y: y.get('city'), x)))

# %%
refined_tweets_df['is_user_india_based'] = refined_tweets_df['user_location_country_code']\
.apply(lambda x: 1 if x == 'in' else 0)

refined_tweets_df['is_tweet_locations_inc_india'] = refined_tweets_df['tweet_locations_country_code']\
.apply(lambda x: 1 if 'in' in x else 0)

# %%
refined_tweets_df.rename(columns = {'user_location': 'user_location_raw', 'geo': 'geo_raw', 
                                    'place': 'place_raw',
                                    'tweet_locations':'tweet_locations_raw'}, inplace = True)

# %%
india_tweets_df = refined_tweets_df.loc[refined_tweets_df['is_tweet_locations_inc_india'] == 1]

# %%
india_tweets_df.head()
# Out:
#             created_at geo_raw     geo_source place_raw             tweet_id  \
# 14 2020-02-01 06:14:49      {}     tweet_text        {}  1223489863552421888
# 31 2020-02-01 22:04:52      {}     tweet_text        {}  1223728952692396032
# 36 2020-02-01 22:06:26      {}  user_location        {}  1223729344432001024
# 41 2020-02-01 22:07:15      {}  user_location        {}  1223729550053584896
# 65 2020-02-01 06:18:41      {}     tweet_text        {}  1223490838589632512
#
#                                   tweet_locations_raw             user_id  \
# 14  [{'country_code': 'fr', 'state': 'Provence-Alp...           955970244
# 31  [{'country_code': 'in'}, {'country_code': 'cn'...            39795026
# 36  [{'country_code': 'in'}, {'country_code': 'cn'...          3014309837
# 41  [{'country_code': 'in'}, {'country_code': 'cn'...           211273540
# 65  [{'country_code': 'ca', 'state': 'Newfoundland...  760700423200247808
#
#                                     user_location_raw  \
# 14                                                 {}
# 31                                                 {}
# 36                             {'country_code': 'fi'}
# 41  {'country_code': 'fr', 'state': 'Ile-de-France...
# 65                                                 {}
#
#    user_location_country_code user_location_state  ... place_country_code  \
# 14                       None                None  ...               None
# 31                       None                None  ...               None
# 36                         fi                None  ...               None
# 41                         fr       Ile-de-France  ...               None
# 65                       None                None  ...               None
#
#    place_state place_county place_city  \
# 14        None         None       None
# 31        None         None       None
# 36        None         None       None
# 41        None         None       None
# 65        None         None       None
#
#                          tweet_locations_country_code  \
# 14                           [fr, gb, us, in, ru, gb]
# 31                                       [in, cn, in]
# 36                                       [in, cn, in]
# 41                                       [in, cn, in]
# 65  [ca, in, om, dk, ee, ye, ir, iq, ro, hr, fr, p...
#
#                                 tweet_locations_state  \
# 14  [Provence-Alpes-Côte d'Azur, England, Kentucky...
# 31                               [None, Hubei, Delhi]
# 36                               [None, Hubei, Delhi]
# 41                               [None, Hubei, Delhi]
# 65  [Newfoundland and Labrador, None, Ad Dakhiliya...
#
#                                tweet_locations_county  \
# 14  [Gap, Gloucestershire, Franklin County, None, ...
# 31                    [None, Jiang'an District, None]
# 36                    [None, Jiang'an District, None]
# 41                    [None, Jiang'an District, None]
# 65  [None, None, None, Favrskov Municipality, Saar...
#
#                                  tweet_locations_city is_user_india_based  \
# 14                [Gap, None, None, None, None, None]                   0
# 31                               [None, Wuhan, Delhi]                   0
# 36                               [None, Wuhan, Delhi]                   0
# 41                               [None, Wuhan, Delhi]                   0
# 65  [None, None, None, None, None, None, None, Non...                   0
#
#    is_tweet_locations_inc_india
# 14                            1
# 31                            1
# 36                            1
# 41                            1
# 65                            1
#
# [5 rows x 26 columns]

# %%
def create_dir(dir_path):
    if not os.path.exists(dir_path):
        os.mkdir(dir_path)

# %%
create_dir(filtered_tweets_files_dir)
india_tweets_df.to_csv(filtered_tweets_file, columns=['tweet_id'], header=False, index=False)

# %%
create_dir(hydrated_tweets_files_dir)
os.system('twarc hydrate ' + filtered_tweets_file + '> ' + hydrated_tweets_file)
# Out:
# 0

# %%
with open(hydrated_tweets_file) as f:
    hydrated_tweets_df = pd.read_json(f, lines = True)

# %%
hydrated_tweets_df.head()
# Out:
#    contributors coordinates          created_at display_text_range  \
# 0           NaN        None 2020-02-01 04:49:03            [0, 74]
# 1           NaN        None 2020-02-01 04:55:33            [0, 73]
# 2           NaN        None 2020-02-01 04:56:05           [0, 140]
# 3           NaN        None 2020-02-01 04:58:16           [0, 147]
# 4           NaN        None 2020-02-01 04:59:04           [0, 281]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [{'text': 'coronavirus', 'indices...
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN               0
# 1  {'media': [{'id': 1223088161053691904, 'id_str...               0
# 2                                                NaN               0
# 3  {'media': [{'id': 1223470542914588674, 'id_str...               1
# 4                                                NaN               3
#
#    favorited                                          full_text   geo  ...  \
# 0      False  RT @AzChike: I respect rob, nigga love his hoo...  None  ...
# 1      False  RT @Ls_Taniaa: Dioss mioo, 1000 puntos en seri...  None  ...
# 2      False  RT @ANI: Air India Spokesperson: Another Air I...  None  ...
# 3      False  #coronavirus: Air India flight lands in New De...  None  ...
# 4      False  The potential for 2nd &amp; 3rd order effects ...  None  ...
#
#    retweet_count  retweeted  \
# 0          14149      False
# 1          11050      False
# 2             57      False
# 3              0      False
# 4              0      False
#
#                                     retweeted_status  scopes  \
# 0  {'created_at': 'Fri Jan 31 21:09:11 +0000 2020...     NaN
# 1  {'created_at': 'Fri Jan 31 03:38:41 +0000 2020...     NaN
# 2  {'created_at': 'Sat Feb 01 04:16:15 +0000 2020...     NaN
# 3                                                NaN     NaN
# 4                                                NaN     NaN
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
# 1  <a href="http://twitter.com/download/iphone" r...      False
# 2  <a href="http://twitter.com/download/android" ...      False
# 3  <a href="http://twitter.com/download/android" ...      False
# 4  <a href="http://twitter.com/download/iphone" r...      False
#
#                                                 user  withheld_copyright  \
# 0  {'id': 3016455522, 'id_str': '3016455522', 'na...                 NaN
# 1  {'id': 2737765863, 'id_str': '2737765863', 'na...                 NaN
# 2  {'id': 65591610, 'id_str': '65591610', 'name':...                 NaN
# 3  {'id': 1068117508501065728, 'id_str': '1068117...                 NaN
# 4  {'id': 374870617, 'id_str': '374870617', 'name...                 NaN
#
#   withheld_in_countries withheld_scope
# 0                   NaN            NaN
# 1                   NaN            NaN
# 2                   NaN            NaN
# 3                   NaN            NaN
# 4                   NaN            NaN
#
# [5 rows x 35 columns]

# %%
hydrated_tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26642 entries, 0 to 26641
# Data columns (total 35 columns):
# contributors                 0 non-null float64
# coordinates                  4 non-null object
# created_at                   26642 non-null datetime64[ns]
# display_text_range           26642 non-null object
# entities                     26642 non-null object
# extended_entities            1493 non-null object
# favorite_count               26642 non-null int64
# favorited                    26642 non-null bool
# full_text                    26642 non-null object
# geo                          4 non-null object
# id                           26642 non-null int64
# id_str                       26642 non-null int64
# in_reply_to_screen_name      1166 non-null object
# in_reply_to_status_id        1089 non-null float64
# in_reply_to_status_id_str    1089 non-null float64
# in_reply_to_user_id          1166 non-null float64
# in_reply_to_user_id_str      1166 non-null float64
# is_quote_status              26642 non-null bool
# lang                         26642 non-null object
# place                        115 non-null object
# possibly_sensitive           3262 non-null float64
# quoted_status                560 non-null object
# quoted_status_id             2499 non-null float64
# quoted_status_id_str         2499 non-null float64
# quoted_status_permalink      2499 non-null object
# retweet_count                26642 non-null int64
# retweeted                    26642 non-null bool
# retweeted_status             23036 non-null object
# scopes                       3 non-null object
# source                       26642 non-null object
# truncated                    26642 non-null bool
# user                         26642 non-null object
# withheld_copyright           4 non-null float64
# withheld_in_countries        6 non-null object
# withheld_scope               4 non-null object
# dtypes: bool(4), datetime64[ns](1), float64(9), int64(4), object(17)
# memory usage: 6.4+ MB

# %%
merged_tweets_df = india_tweets_df.merge(hydrated_tweets_df.rename(columns = {'id':'tweet_id'}), 
                                                                              how='left', on='tweet_id')

# %%
merged_tweets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53909 entries, 0 to 53908
# Data columns (total 60 columns):
# created_at_x                    53909 non-null datetime64[ns]
# geo_raw                         53909 non-null object
# geo_source                      53909 non-null object
# place_raw                       53909 non-null object
# tweet_id                        53909 non-null int64
# tweet_locations_raw             53909 non-null object
# user_id                         53909 non-null int64
# user_location_raw               53909 non-null object
# user_location_country_code      29155 non-null object
# user_location_state             15084 non-null object
# user_location_county            8766 non-null object
# user_location_city              6948 non-null object
# geo_country_code                8 non-null object
# geo_state                       8 non-null object
# geo_county                      4 non-null object
# geo_city                        7 non-null object
# place_country_code              181 non-null object
# place_state                     159 non-null object
# place_county                    88 non-null object
# place_city                      86 non-null object
# tweet_locations_country_code    53909 non-null object
# tweet_locations_state           53909 non-null object
# tweet_locations_county          53909 non-null object
# tweet_locations_city            53909 non-null object
# is_user_india_based             53909 non-null int64
# is_tweet_locations_inc_india    53909 non-null int64
# contributors                    0 non-null float64
# coordinates                     4 non-null object
# created_at_y                    26645 non-null datetime64[ns]
# display_text_range              26645 non-null object
# entities                        26645 non-null object
# extended_entities               1493 non-null object
# favorite_count                  26645 non-null float64
# favorited                       26645 non-null object
# full_text                       26645 non-null object
# geo                             4 non-null object
# id_str                          26645 non-null float64
# in_reply_to_screen_name         1168 non-null object
# in_reply_to_status_id           1091 non-null float64
# in_reply_to_status_id_str       1091 non-null float64
# in_reply_to_user_id             1168 non-null float64
# in_reply_to_user_id_str         1168 non-null float64
# is_quote_status                 26645 non-null object
# lang                            26645 non-null object
# place                           115 non-null object
# possibly_sensitive              3264 non-null float64
# quoted_status                   562 non-null object
# quoted_status_id                2501 non-null float64
# quoted_status_id_str            2501 non-null float64
# quoted_status_permalink         2501 non-null object
# retweet_count                   26645 non-null float64
# retweeted                       26645 non-null object
# retweeted_status                23037 non-null object
# scopes                          3 non-null object
# source                          26645 non-null object
# truncated                       26645 non-null object
# user                            26645 non-null object
# withheld_copyright              4 non-null float64
# withheld_in_countries           6 non-null object
# withheld_scope                  4 non-null object
# dtypes: datetime64[ns](2), float64(12), int64(4), object(42)
# memory usage: 25.1+ MB

# %%
summary_df = pd.DataFrame(columns = )

# %%
create_dir(merged_tweets_files_dir)
merged_tweets_df.to_csv(merged_tweets_file, index=False)

# %%
summary_df.head()
# Out:
# Empty DataFrame
# Columns: [date, total_tweets, tweets_india, tweets_outside_india, user_india, user_outside_india, tweet_with_full_text, tweet_without_full_text]
# Index: []

# %%
cleaned_tweets_df = pd.read_csv(cleaned_tweets_file)

# %%
cleaned_tweets_df.loc[0,'full_text']
# Out:
# 'normala sister talkin of viability gap funding , ppp for creating more hospitals , medical backbone but government of india 🇮🇳 asking &amp; sister orga with scarce resources to prepare to battle #coronavirus #budget2020 10s of orgs set up for emergencies 🤣😭'

# %%
p.set_options(p.OPT.RESERVED, p.OPT.MENTION, p.OPT.URL)
p.tokenize(p.clean(cleaned_tweets_df.loc[0,'full_text'].lower()))
# Out:
# 'normala sister talkin of viability gap funding , ppp for creating more hospitals , medical backbone but government of india 🇮🇳 asking &amp; sister orga with scarce resources to prepare to battle #coronavirus #budget2020 10s of orgs set up for emergencies 🤣😭'

# %%
cleaned_tweets_df.loc[:,'full_text'].apply(lambda x: p.clean(x))
# Out:
# 0        Normala Sister talkin of viability gap funding...
# 1        : Air Indias carrying evacuees from Wuhan has ...
# 2        : Indian already airlifted. This is india. Ism...
# 3        : One takeaway from the coronavirus? Dont puni...
# 4        : An Air India flight carrying Indian national...
# 5        : Coronavirus: Air India plane evacuates India...
# 6        : Dear all, We have created a dedicated URL fo...
# 7        : Relieved to see AI return safely to with of ...
# 8        : India expresses gratitude to China for aidin...
# 9        : I Was Literally Waiting For This: Swami Chak...
# 10                                                       :
# 11       : the flu: *results in hospitalizations and de...
# 12       : Everytime you abuse for its deficient servic...
# 13       : the flu: *results in hospitalizations and de...
# 14       : the flu: *results in hospitalizations and de...
# 15       : Air India special flight to evacuate Indian ...
# 16       : the flu: *results in hospitalizations and de...
# 17       : the flu: *results in hospitalizations and de...
# 18       : the flu: *results in hospitalizations and de...
# 19       : Air India special flight from Delhi lands in...
# 20       : Dear Lord please can you just spare Africa, ...
# 21       : Air India special flight to evacuate Indian ...
# 22       : The national carrier once again comes to the...
# 23       : Air India crew leaving Mumbai to evacuate In...
# 24       : Dear all, We have created a dedicated URL fo...
# 25       : If was a Flight passenger it would be called...
# 26                                                     : -
# 27       : the flu: *results in hospitalizations and de...
# 28       : Don't understand why Endians are surprised o...
# 29       : I respect rob, nigga love his hoodrats. So d...
#                                ...
# 26615    : "Facebook has previously removed medical inf...
# 26616    : the flu: *results in hospitalizations and de...
# 26617    : Air India special flight to evacuate Indian ...
# 26618    : : Feb - GMT:China: &amp; deadThail.:19Japan:...
# 26619    : the flu: *results in hospitalizations and de...
# 26620    : : Indians evacuated from China's Wuhan in sp...
# 26621    : Dear all, We have created a dedicated URL fo...
# 26622    : Dear all, We have created a dedicated URL fo...
# 26623    : Dalam komen banyak palataologist pergi tegur...
# 26624
# 26625    : : Indians evacuated from China's Wuhan in sp...
# 26626    : "I'm not even scared of death, you think I'm...
# 26627    : the flu: *results in hospitalizations and de...
# 26628    : the flu: *results in hospitalizations and de...
# 26629    : Sri Lanka's only patient a Chinese tourist w...
# 26630    : IF WE SURVIVE THIS must make sure that no mo...
# 26631    : the flu: *results in hospitalizations and de...
# 26632
# 26633    China asks India to be rational, cooperate in ...
# 26634    : In Sungai Buloh lies the little-known centre...
# 26635    : the flu: *results in hospitalizations and de...
# 26636    : Sri Lanka's only patient a Chinese tourist w...
# 26637    : Dear , Singapore does not have a border with...
# 26638    The authors read a lot of Infowars/Great game ...
# 26639    : Don't understand why Endians are surprised o...
# 26640    : the flu: *results in hospitalizations and de...
# 26641    : Sri Lanka's only patient a Chinese tourist w...
# 26642    : Dear , I have never asked you for anything b...
# 26643    : the flu: *results in hospitalizations and de...
# 26644    : First batch of Indian passengers start board...
# Name: full_text, Length: 26645, dtype: object

# %%
from clean_tweet import CleanTweet
clean_tweet = CleanTweet()

cleaned_tweets_df.loc[:, 'full_text']
# Out:
# 0        Normala Sister talkin of viability gap funding...
# 1        : Air India’s 747 carrying evacuees from Wuhan...
# 2        : Indian already airlifted. This is india. Ism...
# 3        : One takeaway from the coronavirus? Don’t pun...
# 4        : An Air India flight carrying 324 Indian nati...
# 5        : Coronavirus: Air India plane evacuates 324 I...
# 6        : Dear all, We have created a dedicated URL fo...
# 7        : Relieved to see AI 1349 return safely to #De...
# 8        : India expresses gratitude to China for aidin...
# 9        : I Was Literally Waiting For This: #Indian Sw...
# 10       : #nsfw #xxx #freeporn #hdporn #livesex #porn ...
# 11       : the flu: *results in 500,000 hospitalization...
# 12       : Everytime you abuse for its deficient servic...
# 13       : the flu: *results in 500,000 hospitalization...
# 14       : the flu: *results in 500,000 hospitalization...
# 15       : Air India special flight to evacuate Indian ...
# 16       : the flu: *results in 500,000 hospitalization...
# 17       : the flu: *results in 500,000 hospitalization...
# 18       : the flu: *results in 500,000 hospitalization...
# 19       : #WATCH Air India special flight from Delhi l...
# 20       : Dear Lord please can you just spare Africa, ...
# 21       : Air India special flight to evacuate Indian ...
# 22       : The national carrier once again comes to the...
# 23       : Air India crew leaving Mumbai to evacuate In...
# 24       : Dear all, We have created a dedicated URL fo...
# 25       : If #coronavirus was a Flight passenger it wo...
# 26                 : - حتى مُعانقتك بالخيال تُربك قلبيّ 💛💭
# 27       : the flu: *results in 500,000 hospitalization...
# 28       : Don't understand why Endians are surprised o...
# 29       : I respect rob, nigga love his hoodrats. So d...
#                                ...
# 26615    : "Facebook has previously removed medical inf...
# 26616    : the flu: *results in 500,000 hospitalization...
# 26617    : Air India special flight to evacuate Indian ...
# 26618    : #Coronavirus: Feb 1- 5GMT: China: 11,791 &am...
# 26619    : the flu: *results in 500,000 hospitalization...
# 26620    : #CoronavirusOutbreak: 324 Indians evacuated ...
# 26621    : Dear all, We have created a dedicated URL fo...
# 26622    : Dear all, We have created a dedicated URL fo...
# 26623    : Dalam komen banyak palataologist pergi tegur...
# 26624                      そんなルールがあるとは知りませんでした。ありがとうございます😊
# 26625    : #CoronavirusOutbreak: 324 Indians evacuated ...
# 26626    : "I'm not even scared of death, you think I'm...
# 26627    : the flu: *results in 500,000 hospitalization...
# 26628    : the flu: *results in 500,000 hospitalization...
# 26629    : Sri Lanka's only #CoronaVirus patient a Chin...
# 26630    : IF WE SURVIVE THIS #CoronaVirusOutbreak—we m...
# 26631    : the flu: *results in 500,000 hospitalization...
# 26632                                              می‌فهمم
# 26633    China asks India to be rational, cooperate in ...
# 26634    : In Sungai Buloh lies the little-known centre...
# 26635    : the flu: *results in 500,000 hospitalization...
# 26636    : Sri Lanka's only #CoronaVirus patient a Chin...
# 26637    : Dear , Singapore does not have a border with...
# 26638    The authors read a lot of Infowars/Great game ...
# 26639    : Don't understand why Endians are surprised o...
# 26640    : the flu: *results in 500,000 hospitalization...
# 26641    : Sri Lanka's only #CoronaVirus patient a Chin...
# 26642    : Dear , I have never asked you for anything b...
# 26643    : the flu: *results in 500,000 hospitalization...
# 26644    : #WATCH First batch of Indian passengers star...
# Name: full_text, Length: 26645, dtype: object
